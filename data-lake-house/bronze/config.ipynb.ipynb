# %%
# =====================================================
# SHARED CONFIG — run this from every other notebook
# Usage: %run ../bronze/config
# =====================================================

CATALOG     = "e-commerce-lake-house-project"
BRONZE      = f"{CATALOG}.bronze"
SILVER      = f"{CATALOG}.silver"
GOLD        = f"{CATALOG}.gold"
VOLUME_PATH = "/Volumes/e-commerce-lake-house-project/bronze/source-data/"

# Bronze table names — exactly as ingested
BRONZE_TABLES = {
    "orders":       "olist_orders_table",
    "customers":    "olist_customers_table",
    "order_items":  "olist_order_items_table",
    "payments":     "olist_order_payments_table",
    "reviews":      "olist_order_reviews_table",
    "products":     "olist_products_table",
    "sellers":      "olist_sellers_table",
    "translation":  "product_category_name_translation_table",
    "geolocation":  "olist_geolocation_table",
}

# Silver table names
SILVER_TABLES = {
    "orders":    "silver_orders",
    "customers": "silver_customers",
    "items":     "silver_order_items",
    "products":  "silver_products",
    "payments":  "silver_order_payments",
    "sellers":   "silver_sellers",
    "reviews":   "silver_order_reviews",
}

# Gold table names
GOLD_TABLES = {
    "dim_customers": "dim_customers",
    "dim_products":  "dim_products",
    "dim_sellers":   "dim_sellers",
    "dim_date":      "dim_date",
    "fact_orders":   "fact_orders",
}

print("=" * 45)
print("Config loaded successfully")
print(f"  Catalog : {CATALOG}")
print(f"  Bronze  : {BRONZE}")
print(f"  Silver  : {SILVER}")
print(f"  Gold    : {GOLD}")
print("=" * 45)
