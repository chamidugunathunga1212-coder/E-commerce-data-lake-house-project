# %% [markdown]
# # Run the Configarations

# %%
# %run /Workspace/Users/chamidugunathunga1212@gmail.com/E-commerce-data-lake-house-project/data-lake-house/bronze/config.ipynb

# %% [markdown]
# # Run the initilizations

# %%
from pyspark.sql.functions import (
    col, to_timestamp, upper, trim,
    when, datediff, current_timestamp
)

# %% [markdown]
# # Read the Bronze layer order table

# %%
CATALOG = "e-commerce-lake-house-project"
SCHEMA = "bronze"
TABLE = BRONZE_TABLES['orders']

df_raw = spark.read.table(f"`{CATALOG}`.{SCHEMA}.{TABLE}")
print(f"Bronze rows loaded: {df_raw.count():,}")
display(df_raw.limit(3))
